# %% [markdown]
# <a href="https://colab.research.google.com/github/hm81/gazou/blob/master/lerning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path.append('/content/drive/My Drive/gazoubunrui')

import ic_module as ic

import importlib
importlib.reload(ic)

# 関数実行
ic.Learning(tsnum=30, nb_epoch=50, batch_size=8, learn_schedule=0.9)
# Out:
# >> 学習サンプル数 :  (232, 32, 32, 3)
# >> 学習開始
# Epoch 1/50
# 17/18 [===========================>..] - ETA: 0s - loss: 1.2012 - accuracy: 0.3162
# Epoch 00001: val_loss improved from inf to 1.10447, saving model to best.hdf5
# 18/18 [==============================] - 1s 70ms/step - loss: 1.1944 - accuracy: 0.3169 - val_loss: 1.1045 - val_accuracy: 0.3333
# Epoch 2/50
# 17/18 [===========================>..] - ETA: 0s - loss: 1.0993 - accuracy: 0.3162
# Epoch 00002: val_loss improved from 1.10447 to 1.10199, saving model to best.hdf5
# 18/18 [==============================] - 1s 61ms/step - loss: 1.0966 - accuracy: 0.3239 - val_loss: 1.1020 - val_accuracy: 0.3333
# Epoch 3/50
# 17/18 [===========================>..] - ETA: 0s - loss: 1.0973 - accuracy: 0.4485
# Epoch 00003: val_loss improved from 1.10199 to 1.10131, saving model to best.hdf5
# 18/18 [==============================] - 1s 60ms/step - loss: 1.0972 - accuracy: 0.4507 - val_loss: 1.1013 - val_accuracy: 0.3333
# Epoch 4/50
# ...
